# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("zomato.csv")

# %%
data["dish_liked"][2]
# Out:
# 'Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza'

# %%
data.isna().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df=data.copy()

# %%
df.drop("url",axis=1,inplace=True)

# %%
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
#df.drop("phone",axis=1,inplace=True)
df["phone"]=data["phone"]

# %%
df[["listed_in(city)","location"]]
# Out:
#       listed_in(city)                    location
# 0        Banashankari                Banashankari
# 1        Banashankari                Banashankari
# 2        Banashankari                Banashankari
# 3        Banashankari                Banashankari
# 4        Banashankari                Basavanagudi
# ...               ...                         ...
# 51712      Whitefield                  Whitefield
# 51713      Whitefield                  Whitefield
# 51714      Whitefield                  Whitefield
# 51715      Whitefield  ITPL Main Road, Whitefield
# 51716      Whitefield  ITPL Main Road, Whitefield
#
# [51717 rows x 2 columns]

# %%
df["listed_in(city)"]==df["location"]
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 51712     True
# 51713     True
# 51714     True
# 51715    False
# 51716    False
# Length: 51717, dtype: bool

# %%
df["menu_item"]=data["menu_item"]

# %%
df[df["menu_item"]=="[]"]
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df["location"].value_counts()
# Out:
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
#                          ...
# West Bangalore              6
# Yelahanka                   6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: location, Length: 93, dtype: int64

# %%
df.drop("address",axis=1,inplace=True)

# %%
df["address"]=data["address"]

# %%
# Assigning code to the data
df["code"]=np.arange(1,51718)

# %%
df["name"].nunique()
# Out:
# 8792

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["name"]=data["name"]

# %%
#data[data["name"]=="Cafe Coffee Day"]["phone"].value_counts()

# %%
df["name"].value_counts()
# Out:
# Cafe Coffee Day                                            96
# Onesta                                                     85
# Just Bake                                                  73
# Empire Restaurant                                          71
# Five Star Chicken                                          70
#                                                            ..
# Natis                                                       1
# Shreyas                                                     1
# Vishwas Kabab Centre                                        1
# Taj Biryani Centre                                          1
# Plunge - Sheraton Grand Bengaluru Whitefield Hotel &...     1
# Name: name, Length: 8792, dtype: int64

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                             phone  \
# ...

# %% [markdown]
# ## --------------------------------------------HANDELING THE DUPLICATES---------------------------------------------

# %%
## THERE was LOTS OF DUPLICATE DATA ,I FIGURE OUT THE DUPLICATE DATA ON THE BASIS OF PHONE NUMBER AND ADDRESS

# %%
df_no_dupli=df.drop_duplicates(subset=["phone","address"])

# %%
## SAVING CLEAN FILE FOR FUTURE USE
df_no_dupli.to_csv("CleanData.csv")

# %%
df_no_dupli.shape
# Out:
# (16507, 17)

# %%
# lot of duplicate entries,we reomove duplicates on basis of phone number and address

# %%
df_no_dupli[df_no_dupli["dish_liked"].isna()]
# Out:
#                                                     name online_order  \
# 6        Rosewood International Hotel - Bar & Restaurant           No
# 19                         360 Atoms Restaurant And Cafe          Yes
# 22                                       Cafe Coffee Day           No
# 24                                         Hide Out Cafe           No
# 25                                             CAFE NOVA           No
# ...                                                  ...          ...
# 51614                                      Nawabs Empire           No
# 51627                                 New Shalimar Hotel           No
# 51632                                   SeeYa Restaurant           No
# 51641                                      Andhra Spices           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
#
#       book_table    rate  votes                           phone  \
# ...

# %%
df_no_dupli["dish_liked"].fillna("Not_mentioned",inplace=True)
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\899818176.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["dish_liked"].fillna("Not_mentioned",inplace=True)

# %% [markdown]
# ### 1:-------------------------- DISHES AVAILABLE-----------------------------

# %%
dishes=[]
for i in df_no_dupli["dish_liked"]:
    a=i.split(",")
    for j in a:
        if j is not "NaN":
            dishes.append(j.lower())
# Out:
# <>:5: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:5: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\912541351.py:5: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if j is not "NaN":

# %%
len(set(dishes))
# there are 3437 different dishes available in restorent
# Out:
# 3437

# %% [markdown]
# ### 2:--------------------------------TYPE OF FOOD--------------------------------

# %%
df_no_dupli["cuisines"].isna().sum()
# Out:
# 29

# %%
df_no_dupli["cuisines"].fillna("Not_Mentioned",inplace=True)
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\140005906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["cuisines"].fillna("Not_Mentioned",inplace=True)

# %%
food_type=[]
for i in df_no_dupli["cuisines"]:
    a=i.split(",")
    for j in a:
        if len(j)>1:
            food_type.append(j.lower())

# %%
len(set(food_type))
# Out:
# 191

# %%
## There are 191 different type of food available in data
# there is bug in name of food type

# %%
food_type
# Out:
# ['north indian',
#  ' mughlai',
#  ' chinese',
#  'chinese',
#  ' north indian',
#  ' thai',
#  'cafe',
#  ' mexican',
#  ' italian',
#  'south indian',
#  ' north indian',
#  'north indian',
#  ' rajasthani',
#  'north indian',
#  'north indian',
#  ' south indian',
#  ' andhra',
#  ' chinese',
#  'pizza',
#  ' cafe',
#  ' italian',
#  'cafe',
#  ' italian',
#  ' continental',
#  'cafe',
#  ' mexican',
#  ' italian',
#  ' momos',
#  ' beverages',
#  'cafe',
#  'cafe',
#  ' italian',
#  ' continental',
#  'cafe',
#  ' chinese',
#  ' continental',
#  ' italian',
#  'cafe',
#  ' continental',
#  'cafe',
#  'cafe',
#  ' fast food',
#  ' continental',
#  ' chinese',
#  ' momos',
#  'chinese',
#  ' cafe',
#  ' italian',
#  'cafe',
#  ' italian',
#  ' american',
#  'cafe',
#  ' chinese',
#  ' continental',
#  ' italian',
#  'cafe',
#  ' french',
#  ' north indian',
#  'cafe',
#  ' pizza',
#  ' fast food',
#  ' beverages',
#  'cafe',
#  ' fast food',
#  'italian',
#  ' fast food',
# ...

# %%
## WORKING IN SECONDORY ADDRESS

# %%
secondory=[]
def Secondory_Address(x):
    a=x.split(",")
    if len(a)>3:
        return a[-3]
    else:
        return a[-1]

# %%
df_no_dupli["secondary_address"]=df_no_dupli["address"].apply(Secondory_Address)
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\3718464837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["secondary_address"]=df_no_dupli["address"].apply(Secondory_Address)

# %%
len(set(df_no_dupli["location"]))
# there  are 94 locations are availble in the dataset
# Out:
# 94

# %% [markdown]
# ### I made seperate Frame for review section

# %%
reviews=pd.DataFrame(df_no_dupli[["reviews_list","code"]])
df_no_dupli.drop("reviews_list",axis=1,inplace=True)
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\54348147.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli.drop("reviews_list",axis=1,inplace=True)

# %% [markdown]
# ### 3:--------------------WORKING ON MENU ITEM COLUMN-------------------------------

# %%
df_no_dupli[df_no_dupli["menu_item"]!="[]"]
# Out:
#                                name online_order book_table    rate  votes  \
# 32                      Sweet Truth          Yes         No   3.9/5     35
# 34                           Faasos          Yes         No   4.2/5    415
# 39     Maruthi Davangere Benne Dosa          Yes         No   4.0/5     17
# 46                   Kitchen Garden          Yes         No   3.6/5    244
# 47                           Recipe          Yes         No   4.0/5    804
# ...                             ...          ...        ...     ...    ...
# 51414                  Bao & Grills          Yes         No  3.0 /5    112
# 51509                  Purani Dehli          Yes         No  3.5 /5     75
# 51586                   Quick Bites          Yes         No     NEW      0
# 51587            Shrawan Restaurant          Yes         No     NaN      0
# 51620                Fujian Express          Yes         No  3.8 /5    182
#
# ...

# %% [markdown]
# ### i think menu item column is helpful when a costomer ordering food from perticular restorent,Lots of items are covered in dishes.I will use this column at the end.

# %%
## i think menu item column is helpful when a costomer ordering food from perticular restorent,Lots of items are covered in dishes.I will use this column at the end.
Menu_Items_reserved=pd.DataFrame(df_no_dupli[["menu_item","code"]])
df_no_dupli.drop("menu_item",axis=1,inplace=True)
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\2543884807.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli.drop("menu_item",axis=1,inplace=True)

# %%
df_no_dupli
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51628        Nook - Aloft Bengaluru Cessna Business Park           No
# 51632                                   SeeYa Restaurant           No
# 51641                                      Andhra Spices           No
# 51677                                            Bhagini           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
#
#       book_table    rate  votes                             phone  \
# ...

# %% [markdown]
# ### 4:------------------------------WORKING ON PHONE NUMBER COLUMN------------------------------------
# #### lots of cleaning required for it

# %%
df_no_dupli["phone_clean"]=df_no_dupli['phone'].str.replace("\r\n",",")
df_no_dupli["phone_clean"].fillna("not_mentioned",inplace=True)
df_no_dupli["phone_clean"]=df_no_dupli["phone_clean"].str.replace("\n","")
df_no_dupli["phone_clean"]=df_no_dupli["phone_clean"].str.replace(" ","")
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\2271120624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["phone_clean"]=df_no_dupli['phone'].str.replace("\r\n",",")
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\2271120624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["phone_clean"].fillna("not_mentioned",inplace=True)
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\2271120624.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_no_dupli.head(20)
# Out:
#                                                  name online_order book_table  \
# 0                                               Jalsa          Yes        Yes
# 1                                      Spice Elephant          Yes         No
# 2                                     San Churro Cafe          Yes         No
# 3                               Addhuri Udupi Bhojana           No         No
# 4                                       Grand Village           No         No
# 5                                     Timepass Dinner          Yes         No
# 6     Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                              Onesta          Yes        Yes
# 8                                      Penthouse Cafe          Yes         No
# 9                                           Smacznego          Yes         No
# 10  CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes         No
# ...

# %% [markdown]
# #### i will make a seperate frame for phone numbers

# %%
## i will make a seperate frame for phone numbers
Phone_Details=pd.DataFrame(df_no_dupli[["code","phone_clean"]])

# %%
def PrimaryPhoneNumber(x):
    a=x.split(",")
    if len(a)>=1:
        return a[0]
    else:
        return "Not Available"

# %%
Phone_Details["phone_clean2"]=Phone_Details["phone_clean"].apply(PrimaryPhoneNumber)

# %% [raw]
#  #### HANDELING PHONE NUMBERS:
#     > lots of phone numbers starts with different way
#     > + was most common in it ,I removed it,
#     >some rows have more than 1 number,I split them into differern

# %%
def PhoneCleaning(x):
    
    if(x[:4]=="0091"):
        x=x[4:]
        return x
    
        print(x,len(x))
    elif(x[0:3]=="+91"):
        x=x[3:]
        return x
        print(x,len(x))
    elif(x[0:3]=="091"):
        x=x[1:]
        return x
        print(x,len(x)) 
    elif(x[0:3]=="000"):
        x=x[3:]
        return x
        print(x,len(x)) 
    
        
    elif(x[0]=="0"):
        x=x[1:]
        return x
        print(x,len(x))
    
    else:
        return x
        print(x,len(x))

# %%
Phone_Details["phone_clean3"]=Phone_Details["phone_clean2"].apply(PhoneCleaning)

# %%
#Phone_Details.drop("extra",axis=1,inplace=True)

# %%
Phone_Details["phone_clean3"]=Phone_Details["phone_clean2"].apply(PhoneCleaning)

# %%
### here i perform various operation on columns

# %%
Phone_Details
# Out:
#         code                  phone_clean                phone_clean2  \
# 0          1    08042297555,+919743772233                 08042297555
# 1          2                  08041714161                 08041714161
# 2          3                +919663487993               +919663487993
# 3          4                +919620009302               +919620009302
# 4          5  +918026612447,+919901210005               +918026612447
# ...      ...                          ...                         ...
# 51628  51629   +919663517066+919686861135  +919663517066+919686861135
# 51632  51633                +919164562939               +919164562939
# 51641  51642                not_mentioned               not_mentioned
# 51677  51678                  08065951222                 08065951222
# 51714  51715                not_mentioned               not_mentioned
#
#                   phone_clean3
# 0                   8042297555
# 1                   8041714161
# ...

# %%
### This is the code for seperating phone numbers from the raw data

# %%
def CheckingPrimaryNumber(x):
     if "+" in x:
        return x.split("+")[0]
     else:
        return x
    
def CheckingSecondoryNumber(x):
    if "+" in x:
        return x.split("+")[-1]
    else:
        return "Not Available"

# %%
# Applying above function to extract primary and secondory phone numbers
Phone_Details["PrimaryyNumber"]=Phone_Details["phone_clean3"].apply(CheckingPrimaryNumber)
Phone_Details["SecondoryNumber"]=Phone_Details["phone_clean3"].apply(CheckingSecondoryNumber)

# %%
# renaming value
Phone_Details["PrimaryyNumber"].replace("not_mentioned","Not Available",inplace=True)

# %%
Phone_Details
# Out:
#         code                  phone_clean                phone_clean2  \
# 0          1    08042297555,+919743772233                 08042297555
# 1          2                  08041714161                 08041714161
# 2          3                +919663487993               +919663487993
# 3          4                +919620009302               +919620009302
# 4          5  +918026612447,+919901210005               +918026612447
# ...      ...                          ...                         ...
# 51628  51629   +919663517066+919686861135  +919663517066+919686861135
# 51632  51633                +919164562939               +919164562939
# 51641  51642                not_mentioned               not_mentioned
# 51677  51678                  08065951222                 08065951222
# 51714  51715                not_mentioned               not_mentioned
#
#                   phone_clean3 PrimaryyNumber SecondoryNumber
# 0                   8042297555     8042297555   Not Available
# ...

# %%
### Our Clean DataFrame of the Phone Numbers
FinalPhoneDetails=Phone_Details[["code","PrimaryyNumber","SecondoryNumber"]]

# %%
FinalPhoneDetails
#I will save this file for further use
FinalPhoneDetails.to_csv("CleanNumbers.csv")

# %%
#  After doing lots of data cleaning i get following result
FinalPhoneDetails
# Out:
#         code PrimaryyNumber SecondoryNumber
# 0          1     8042297555   Not Available
# 1          2     8041714161   Not Available
# 2          3     9663487993   Not Available
# 3          4     9620009302   Not Available
# 4          5     8026612447   Not Available
# ...      ...            ...             ...
# 51628  51629     9663517066    919686861135
# 51632  51633     9164562939   Not Available
# 51641  51642  Not Available   Not Available
# 51677  51678     8065951222   Not Available
# 51714  51715  Not Available   Not Available
#
# [16507 rows x 3 columns]

# %% [markdown]
# ### 5:---------------------------WORKING WITH RESTORENT TYPE-----------------------------

# %%
type_of_resto=[]
for i in df_no_dupli["rest_type"]:
    type_of_resto.append(str(i).lower())

# %%
#Note:please use this function twice to get correct output
def CheckingRestroType(x):
    
    x=str(x).lower()
    
    x=x.split(",")
    #print(len(x))
#     if len(x)==1:
#         return (x[0])
    if len(x)==2:
        return (x[1])
        return UniqueRestoTYpe.append(x[1])
    elif len(x)==3:
        return (x[1])
        return (x[1].lower())
        UniqueRestoTYpe.append(x[2])

# %%
Resto1=df_no_dupli["rest_type"].apply(CheckingRestroType)

# %%
Resto2=df_no_dupli["rest_type"].apply(CheckingRestroType)

# %%
Resto1
# Out:
# 0                  None
# 1                  None
# 2         casual dining
# 3                  None
# 4                  None
#               ...
# 51628              None
# 51632              None
# 51641              None
# 51677               bar
# 51714              None
# Name: rest_type, Length: 16507, dtype: object

# %%
df_no_dupli["rest_type"].head(101)
# Out:
# 0            Casual Dining
# 1            Casual Dining
# 2      Cafe, Casual Dining
# 3              Quick Bites
# 4            Casual Dining
#               ...
# 98             Quick Bites
# 99          Dessert Parlor
# 100            Quick Bites
# 101            Quick Bites
# 102            Quick Bites
# Name: rest_type, Length: 101, dtype: object

# %%
UniqueRestoTYpe=(list(set(Resto1))+list(set(Resto2)))

# %%
#UniqueRestoTYpe.remove("nan")
#UniqueRestoTYpe.remove("nan")
UniqueRestoTYpe.remove(None)

# %%
## Here are the all unique restorent type available in data
## we will use them further for making model
len((UniqueRestoTYpe))
# Out:
# 35

# %%
df_no_dupli
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51628        Nook - Aloft Bengaluru Cessna Business Park           No
# 51632                                   SeeYa Restaurant           No
# 51641                                      Andhra Spices           No
# 51677                                            Bhagini           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
#
#       book_table    rate  votes                             phone  \
# ...

# %% [markdown]
# ### 6:------------------------------WORKING WITH RATING COLUMN--------------------

# %%
df_no_dupli["rate"]
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51628    4.2 /5
# 51632    3.3 /5
# 51641    3.2 /5
# 51677    2.5 /5
# 51714       NaN
# Name: rate, Length: 16507, dtype: object

# %%
#Lots of na values are present in data
df_no_dupli["rate"].isna().sum()
# Out:
# 2619

# %%
# most of the restorent are not voted ,hense  they are unrated
# we have to replace those restorent rating to 0
df_no_dupli[df_no_dupli["rate"].isna()]["votes"].value_counts()
# Out:
# 0       2615
# 2497       1
# 1221       1
# 10         1
# 6          1
# Name: votes, dtype: int64

# %%
df_no_dupli[(df_no_dupli["rate"].isna())&(df_no_dupli["votes"]==0)]["rate"].fillna(0,inplace=True)
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\1469757455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli[(df_no_dupli["rate"].isna())&(df_no_dupli["votes"]==0)]["rate"].fillna(0,inplace=True)

# %%
df_no_dupli[(df_no_dupli["rate"].isna())&(df_no_dupli["votes"]==0)]
# Out:
#                                                     name online_order  \
# 84                                             Chill Out           No
# 90                                        Me And My Cake           No
# 91                                               Sunsadm           No
# 92                                Annapooraneshwari Mess           No
# 107                                        Coffee Shopee           No
# ...                                                  ...          ...
# 51578                                    The Yellow Stop           No
# 51579                                 Arabian Fame Grill           No
# 51587                                 Shrawan Restaurant          Yes
# 51627                                 New Shalimar Hotel           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
#
#       book_table rate  votes                           phone  \
# 84            No  NaN      0                  +91 9341215167
# ...

# %%
# There are only 4 resto which have voted but not rated
df_no_dupli[(df_no_dupli["rate"].isna()) & (df_no_dupli["votes"]!=0)].shape
# Out:
# (4, 17)

# %%
#

# %%
# replacing all na values to zero
# we have to deal to those 4 values whose votes are not 0
df_no_dupli["rate"].fillna(0,inplace=True)
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\4275923156.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["rate"].fillna(0,inplace=True)

# %%
df_no_dupli[(df_no_dupli["rate"].isna())& (df_no_dupli["votes"]==0)]
# Out:
# Empty DataFrame
# Columns: [name, online_order, book_table, rate, votes, phone, location, rest_type, dish_liked, cuisines, approx_cost(for two people), listed_in(type), listed_in(city), address, code, secondary_address, phone_clean]
# Index: []

# %%
# Making new rating column after splitting
df_no_dupli["rating"]=df_no_dupli["rate"].apply(lambda x:str(x).split("/")[0])
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\1973513534.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["rating"]=df_no_dupli["rate"].apply(lambda x:str(x).split("/")[0])

# %%
#there are only 4 values in data which are unrated but have votings
#this number is very small,i will set them to avarage rating for that location

# %%
df_no_dupli[(df_no_dupli["rating"]=="0")&(df_no_dupli["votes"]!=0)]
# Out:
#                          name online_order book_table rate  votes  \
# 21037  Shivaji Military Hotel           No         No    0   2497
# 21288                Kesariya           No        Yes    0   1221
# 21445              Brew Point           No         No    0     10
# 21452          Gam's Delicacy           No         No    0      6
#
#                                   phone   location      rest_type  \
# 21037  +91 9845149217\r\n+91 9980739217  Jayanagar  Casual Dining
# 21288    080 26590800\r\n+91 9844986893   JP Nagar  Casual Dining
# 21445                               NaN   JP Nagar           Cafe
# 21452                    +91 8837001496   JP Nagar  Casual Dining
#
#                                               dish_liked  \
# 21037  Mutton Biryani, Mutton Fry, Donne Biryani, Chi...
# 21288  Kheer, Fruit Cream, Panipuri, Rajasthani Thali...
# 21445                                      Not_mentioned
# 21452                                      Not_mentioned
#
# ...

# %%
# Some restaurents are new and not rated yet by customer
# we will change is rating from NEW to 0 rating2
df_no_dupli["rating"].replace("NEW",0,inplace=True)
df_no_dupli[df_no_dupli["rating"]==0]
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\4039977990.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["rating"].replace("NEW",0,inplace=True)
#                             name online_order book_table rate  votes  \
# 72                 Spicy Tandoor           No         No  NEW      0
# 75         Om Sri Vinayaka Chats           No         No  NEW      0
# 110          Hari Super Sandwich           No         No  NEW      0
# 130         Roll Magic Fast Food           No         No  NEW      0
# 131    Foodlieious Multi Cuisine           No         No  NEW      0
# ...                          ...          ...        ...  ...    ...
# 50900           Nawab Di Biryani          Yes         No  NEW      0
# ...

# %%
df_no_dupli["rating"].replace("-","0",inplace=True)
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\4243435090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["rating"].replace("-","0",inplace=True)

# %%
# changing the data type of rating column to integer
df_no_dupli["rating"]=df_no_dupli["rating"].astype("float")
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\2226085261.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["rating"]=df_no_dupli["rating"].astype("float")

# %%
df_no_dupli.groupby("location")["rating"].mean().head(60)
#Jayanagar                     3.237649
#JP Nagar                      2.743417
df_no_dupli[(df_no_dupli["rating"]=="0")&(df_no_dupli["votes"]!=0)]
# Out:
# Empty DataFrame
# Columns: [name, online_order, book_table, rate, votes, phone, location, rest_type, dish_liked, cuisines, approx_cost(for two people), listed_in(type), listed_in(city), address, code, secondary_address, phone_clean, rating]
# Index: []

# %%
df_no_dupli[(df_no_dupli["rating"]==0) & (df_no_dupli["votes"]!=0)]
df_no_dupli[df_no_dupli.index==21037].rating.replace(0.0,3.237649,inplace=True)
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\1858661942.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli[df_no_dupli.index==21037].rating.replace(0.0,3.237649,inplace=True)

# %%
df_no_dupli.groupby("location")["rating"].groups['Jayanagar'].shape[0]
21038
21289
21446
21453
# Out:
# 21453

# %%
df_no_dupli[(df_no_dupli["rating"]==0) & (df_no_dupli["votes"]!=0)]
# Out:
#                          name online_order book_table rate  votes  \
# 21037  Shivaji Military Hotel           No         No    0   2497
# 21288                Kesariya           No        Yes    0   1221
# 21445              Brew Point           No         No    0     10
# 21452          Gam's Delicacy           No         No    0      6
#
#                                   phone LocationInCity      rest_type  \
# 21037  +91 9845149217\r\n+91 9980739217      Jayanagar  Casual Dining
# 21288    080 26590800\r\n+91 9844986893       JP Nagar  Casual Dining
# 21445                               NaN       JP Nagar           Cafe
# 21452                    +91 8837001496       JP Nagar  Casual Dining
#
#                                               dish_liked  \
# 21037  Mutton Biryani, Mutton Fry, Donne Biryani, Chi...
# 21288  Kheer, Fruit Cream, Panipuri, Rajasthani Thali...
# 21445                                      Not_mentioned
# ...

# %%
df_no_dupli[df_no_dupli["code"]==21038].rating=3
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\2568833401.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli[df_no_dupli["code"]==21038].rating=3

# %%
# here i am not geting the way to substitute the value,I will change this value by using excel
df_no_dupli.to_csv("clean(sub_value).csv")

# %% [markdown]
# ### --------------WORKING WITH LISTED IN(TYPE)| TYPE OF RESTORENT--------------------

# %%
df_no_dupli["listed_in(type)"].value_counts()
# Out:
# Delivery              10632
# Dine-out               4030
# Desserts                728
# Cafes                   651
# Buffet                  387
# Drinks & nightlife       47
# Pubs and bars            32
# Name: listed_in(type), dtype: int64

# %%
df_no_dupli["listed_in(type)"].isna().sum()
# Out:
# 0

# %%
#lowering the strings
df_no_dupli["listed_in(type)"]=df_no_dupli["listed_in(type)"].apply(lambda x:x.lower())
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\2728045152.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["listed_in(type)"]=df_no_dupli["listed_in(type)"].apply(lambda x:x.lower())

# %%
df_no_dupli[df_no_dupli["location"]!=df_no_dupli["listed_in(city)"]]
# Out:
#                                                   name online_order  \
# 4                                        Grand Village           No
# 5                                      Timepass Dinner          Yes
# 6      Rosewood International Hotel - Bar & Restaurant           No
# 29                                    Srinathji's Cafe           No
# 30                                           Redberrys          Yes
# ...                                                ...          ...
# 51620                                   Fujian Express          Yes
# 51627                               New Shalimar Hotel           No
# 51628      Nook - Aloft Bengaluru Cessna Business Park           No
# 51632                                 SeeYa Restaurant           No
# 51641                                    Andhra Spices           No
#
#       book_table    rate  votes                             phone  \
# 4             No   3.8/5    166  +91 8026612447\r\n+91 9901210005
# ...

# %%
df_no_dupli.rename(columns={"listed_in(city)":"City","location":"LocationInCity"},inplace=True)
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\4105133147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli.rename(columns={"listed_in(city)":"City","location":"LocationInCity"},inplace=True)

# %% [markdown]
# ### ------------------------------WORKING ON APPROX_COST(FOR TWO PEOPLE)-----------------------------------

# %%
#There are some na values,We have to handle them
df_no_dupli["approx_cost(for two people)"].isna().sum()
# Out:
# 116

# %%
# changing datatype to float
df_no_dupli["approx_cost(for two people)"]=df_no_dupli["approx_cost(for two people)"].str.replace(",","")
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\3139273683.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["approx_cost(for two people)"]=df_no_dupli["approx_cost(for two people)"].str.replace(",","")

# %%
df_no_dupli["approx_cost(for two people)"].dtype
# Out:
# dtype('O')

# %%
# I have to change the datatype but it contains null values,So i replaced them with -1 to change the type.I will handel these -1 values later
df_no_dupli["approx_cost(for two people)"].fillna(-1,inplace=True)
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\936562660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["approx_cost(for two people)"].fillna(-1,inplace=True)

# %%
df_no_dupli["approx_cost(for two people)"]=df_no_dupli["approx_cost(for two people)"].astype("int")
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\3862455978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli["approx_cost(for two people)"]=df_no_dupli["approx_cost(for two people)"].astype("int")

# %%
df_no_dupli[df_no_dupli["approx_cost(for two people)"]==-1]
# Out:
#                                  name online_order book_table    rate  votes  \
# 1662                  Papa Khan Rasoi           No         No       0      0
# 1768                           Innate           No         No       0      0
# 1795   Super Chef's (New Royal treat)           No         No       0      0
# 3774         The Hub - Ibis Bengaluru           No         No   3.9/5    237
# 3954             North Indian Kitchen           No         No   3.2/5     13
# ...                               ...          ...        ...     ...    ...
# 50647                   Mast Kalandar           No         No  2.6 /5     76
# 50702            Karavalli Food Court           No         No  3.2 /5      4
# 50764                          Innate           No         No       0      0
# 50940                        Cinnabon           No         No  4.0 /5     80
# 51641                   Andhra Spices           No         No  3.2 /5      4
#
# ...

# %%
# Here I  take mean of approx cost according to location
df_no_dupli.groupby('City')["approx_cost(for two people)"].mean().round(-2)
# Out:
# City
# BTM                      500.0
# Banashankari             400.0
# Bannerghatta Road        400.0
# Basavanagudi             400.0
# Bellandur                500.0
# Brigade Road             700.0
# Brookefield              500.0
# Church Street            600.0
# Electronic City          500.0
# Frazer Town              500.0
# HSR                      400.0
# Indiranagar              500.0
# JP Nagar                 400.0
# Jayanagar                400.0
# Kalyan Nagar             500.0
# Kammanahalli             500.0
# Koramangala 4th Block    600.0
# Koramangala 5th Block    400.0
# Koramangala 6th Block    600.0
# Koramangala 7th Block    400.0
# Lavelle Road             800.0
# MG Road                  600.0
# Malleshwaram             500.0
# Marathahalli             500.0
# New BEL Road             400.0
# Old Airport Road         600.0
# Rajajinagar              400.0
# Residency Road           600.0
# Sarjapur Road            500.0
# Whitefield               600.0
# ...

# %%
# Here I store the index and values (mean) according to City location
a=df_no_dupli.groupby('City')["approx_cost(for two people)"].mean().round(-2).index
b=df_no_dupli.groupby('City')["approx_cost(for two people)"].mean().round(-2).values

# %%
# created dictionary to store above key-value pair
d=dict()

# %%
#dictionry_storing
for i in range(len(a)):
    d[a[i]]=b[i]

# %%
# I extracted cost and City from our dataframe to apply some function on it
City_=[]
cost=[]

for i in df_no_dupli["City"]:
    City_.append(i)
    
for i in df_no_dupli["approx_cost(for two people)"]:
    cost.append(i)

# %%
for i in  range(len(City_)):
                
    if cost[i]==-1:
        city=City_[i]
        cost[i]=d[city]
        
#finally,appending list to the dataframe      
df_no_dupli["cost"]=cost

# %%
df_no_dupli.isna().sum()
# Out:
# name                             0
# online_order                     0
# book_table                       0
# rate                             0
# votes                            0
# phone                          346
# LocationInCity                  11
# rest_type                       86
# dish_liked                       0
# cuisines                         0
# approx_cost(for two people)      0
# listed_in(type)                  0
# City                             0
# address                          0
# code                             0
# secondary_address                0
# phone_clean                      0
# rating                           0
# cost                             0
# dtype: int64

# %%
df_no_dupli
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51628        Nook - Aloft Bengaluru Cessna Business Park           No
# 51632                                   SeeYa Restaurant           No
# 51641                                      Andhra Spices           No
# 51677                                            Bhagini           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
#
#       book_table    rate  votes                             phone  \
# ...

# %% [markdown]
# ### ---------------------------------------------- WORKING WITH LOCATIONS-------------------------------

# %%
from geopy.geocoders import Nominatim

# %%
def FindLatitude(x):
    loc = Nominatim(user_agent="MyApp")
    getLoc = loc.geocode(x)
    print(getLoc.latitude)

def FindLongitude(x):
    loc = Nominatim(user_agent="MyApp")
    getLoc = loc.geocode(x)
    return getLoc.longitude

# %% [markdown]
# ###  -----------------------DATAFRAME AFTER APPLYING CHANGES--------------------------

# %%
df_no_dupli.drop(["phone","approx_cost(for two people)","approx_cost(for two people)","phone_clean","rate"],axis=1,inplace=True)
# Out:
# C:\Users\vipul ghadi\AppData\Local\Temp\ipykernel_3036\2374218252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_dupli.drop(["phone","approx_cost(for two people)","approx_cost(for two people)","phone_clean","rate"],axis=1,inplace=True)

# %%
frame=pd.merge(df_no_dupli,Phone_Details[["code","PrimaryyNumber","SecondoryNumber"]],on=df_no_dupli["code"])

# %%
frame.columns
# Out:
# Index(['key_0', 'name', 'online_order', 'book_table', 'votes',
#        'LocationInCity', 'rest_type', 'dish_liked', 'cuisines',
#        'listed_in(type)', 'City', 'address', 'code_x', 'secondary_address',
#        'rating', 'cost', 'code_y', 'PrimaryyNumber', 'SecondoryNumber'],
#       dtype='object')

# %%
frame.drop(["key_0","code_y"],axis=1,inplace=True)

# %% [markdown]
# ### -----------------------------------------------------------------------------------------------------------
